# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import os
from collections import defaultdict

# %%
directory = "../logs"

tasks = ["pendulum_regression", "pendulum_interpolation", "activity_classification","physionet_interpolation", "rotating_mnist" ]

experiments = defaultdict(list)
for task in tasks:
    for log_file in os.listdir(directory):
        if task in log_file:
            filename = os.path.join(directory,log_file)
            if filename.endswith(".json"):      
                print(filename)      
                with open(filename, 'r') as f:
                    dic = json.load(f)
                    if dic["final"]["epoch"] == 990:
                        if task == "physionet_interpolation":
                            experiments[f'{task}_{dic["args"]["sample_tp"]}'].append(dic['final'])
                        else:
                            experiments[task].append(dic['final'])
# Out:
# ../logs/pendulum_regression_5328.json
# ../logs/pendulum_regression_53864.json
# ../logs/pendulum_regression_87399.json
# ../logs/pendulum_regression_10850.json
# ../logs/pendulum_regression_72986.json
# ../logs/pendulum_regression_43325.json
# ../logs/pendulum_regression_68092.json
# ../logs/pendulum_regression_56207.json
# ../logs/pendulum_regression_65334.json
# ../logs/pendulum_regression_9790.json
# ../logs/pendulum_interpolation_76020.json
# ../logs/pendulum_interpolation_5910.json
# ../logs/pendulum_interpolation_14474.json
# ../logs/pendulum_interpolation_93831.json
# ../logs/pendulum_interpolation_61052.json
# ../logs/pendulum_interpolation_56807.json
# ../logs/pendulum_interpolation_59211.json
# ../logs/pendulum_interpolation_36438.json
# ../logs/pendulum_interpolation_77345.json
# ../logs/pendulum_interpolation_63339.json
# ../logs/pendulum_interpolation_79478.json
# ../logs/pendulum_interpolation_40940.json
# ../logs/pendulum_interpolation_34971.json
# ../logs/pendulum_interpolation_19179.json
# ../logs/pendulum_interpolation_48126.json
# ../logs/activity_classification_6345.json
# ../logs/activity_classification_37643.json
# ../logs/activity_classification_79822.json
# ../logs/activity_classification_53886.json
# ../logs/activity_classification_93806.json
# ../logs/activity_classification_66627.json
# ../logs/activity_classification_67893.json
# ../logs/activity_classification_65025.json
# ../logs/activity_classification_68604.json
# ../logs/physionet_interpolation_0.5_6741.json
# ../logs/physionet_interpolation_0.5_32011.json
# ../logs/physionet_interpolation_0.5_47538.json
# ../logs/physionet_interpolation_0.5_92616.json
# ../logs/physionet_interpolation_0.5_54712.json
# ../logs/physionet_interpolation_0.5_89834.json
# ../logs/physionet_interpolation_0.5_52208.json
# ../logs/physionet_interpolation_0.5_23519.json
# ../logs/physionet_interpolation_0.5_32764.json
# ../logs/rotating_mnist_83802.json
# ../logs/rotating_mnist_80259.json
# ../logs/rotating_mnist_48682.json
# ../logs/rotating_mnist_15035.json
# ../logs/rotating_mnist_2671.json
# ../logs/rotating_mnist_30475.json
# ../logs/rotating_mnist_25401.json
# ../logs/rotating_mnist_45779.json
# ../logs/rotating_mnist_78074.json
# ../logs/rotating_mnist_1425.json
# ../logs/rotating_mnist_85691.json

# %%
summarized = defaultdict(dict)
for task in experiments.keys():
    for key in experiments[task][0].keys():
        summarized[task][key] = [experiment[key] for experiment in experiments[task]]

# %%
for task in summarized.keys():
    print(task, len(summarized[task]['trn_elbo']))
# Out:
# pendulum_regression 8
# pendulum_interpolation 11
# activity_classification 8
# physionet_interpolation_0.5 8
# rotating_mnist 10

# %%
def gen_table(exp, key, scale, prec=2):
    l = len(exp[key])
    r1 = f"|      Run     |     Mean    |" + "".join([f"   {i}   |" for i in range(1,l+1)]) + "\n"
    r2 = f"| -------------| ----------- |" + "".join([f" ----- |" for i in range(1,l+1)]) + "\n"
    r3 =  (f"|{key} | {exp[key].mean()*scale:.{prec}f} \u00B1 {exp[key].std()*scale:.{prec}f}|" 
    +"".join([ f" {x*scale:.{prec}f} |" for x in exp[key].values])
    )
    return r1 + r2 + r3

# %%
import pandas as pd 
# task = 'physionet_interpolation_0.5'
task = 'activity_classification'
exp = pd.DataFrame.from_dict(summarized[task])
target = 'tst_aux_acc*'

print(gen_table(exp, target, 100, prec=2))
print(exp)
# Out:
# |      Run     |     Mean    |   1   |   2   |   3   |   4   |   5   |   6   |   7   |   8   |
# | -------------| ----------- | ----- | ----- | ----- | ----- | ----- | ----- | ----- | ----- |
# |tst_aux_acc* | 90.58 ± 0.48| 90.03 | 90.82 | 90.64 | 90.78 | 90.22 | 89.91 | 91.12 | 91.14 |
#    trn_loss  trn_elbo    trn_kl0       trn_klp  trn_log_pxz  trn_aux_val  \
# 0 -0.166629 -0.234294  55.928303  13061.939096   -36.463468     0.006767
# 1 -0.189094 -0.250202  55.973752  14803.383114   -39.023938     0.006111
# 2 -0.207947 -0.273369  55.930261  13100.706892   -42.329285     0.006542
# 3 -0.179430 -0.243604  55.912941  13260.945647   -37.880083     0.006417
# 4  0.206266  0.015034  55.346198  12449.186306     1.003128     0.019123
# 5  0.206579  0.014839  55.215253  12449.401103     0.973840     0.019174
# 6 -0.189289 -0.253822  55.945511  13825.852842   -39.469383     0.006453
# 7 -0.171779 -0.236753  55.959229  14236.256106   -36.949680     0.006497
#
#    tst_loss  tst_aux_val  tst_aux_acc  tst_elbo_val  ...  tst_aux_acc*  \
# 0  5.226527     0.533799     0.904916     -0.111466  ...      0.900321
# 1  4.908060     0.503096     0.905389     -0.122900  ...      0.908168
# 2  5.245941     0.533060     0.903985     -0.084663  ...      0.906443
# 3  5.318310     0.540625     0.903221     -0.087942  ...      0.907786
# 4  4.928566     0.489875     0.896031      0.029814  ...      0.902198
# 5  5.500353     0.547330     0.895282      0.027051  ...      0.899114
# 6  5.009479     0.513064     0.904443     -0.121156  ...      0.911237
# 7  4.804101     0.492081     0.907420     -0.116711  ...      0.911389
#
#    val_loss  val_aux_val  val_aux_acc  val_elbo_val  val_elbo_kl0  \
# 0  4.695936     0.480019     0.915348     -0.104259     55.903783
# 1  4.236628     0.434796     0.915920     -0.111333     55.962579
# 2  4.213244     0.428984     0.918036     -0.076592     55.899583
# 3  4.790162     0.485361     0.912526     -0.063443     55.886816
# 4  4.960474     0.491272     0.897331      0.047756     55.397274
# 5  5.037189     0.499000     0.895882      0.047188     55.227188
# 6  4.852109     0.494725     0.911001     -0.095143     55.925091
# 7  4.156548     0.424870     0.918360     -0.092154     55.952271
#
#    val_elbo_klp  val_elbo_log_pxz  val_aux_acc*  epoch
# 0  13746.942941        -17.028906      0.920095    990
# 1  15844.495822        -18.300283      0.924233    990
# 2  12452.130423        -12.750316      0.922498    990
# 3  13763.592705        -10.908216      0.917693    990
# 4  12472.693744          5.905386      0.907569    990
# 5  12723.681108          5.795083      0.909571    990
# 6  14048.333383        -15.691948      0.917121    990
# 7  15142.423740        -15.352459      0.921640    990
#
# [8 rows x 23 columns]

# %%
exp
# Out:
#    trn_loss  trn_elbo    trn_kl0        trn_klp  trn_log_pxz  tst_loss  \
# 0  0.311623  0.311623  55.993642  115290.676389  2675.900239  0.338022
# 1  0.311633  0.311633  55.993793  115068.064236  2676.012012  0.336738
# 2  0.311534  0.311534  55.993468  111676.097569  2675.499186  0.335471
# 3  0.311478  0.311478  55.993793  115261.109375  2674.658084  0.337112
# 4  0.311591  0.311591  55.993349  122807.135069  2674.877089  0.335856
# 5  0.311099  0.311099  55.993793  113321.648785  2671.581261  0.336702
# 6  0.312182  0.312182  55.993425  112962.785069  2680.957422  0.337059
# 7  0.311489  0.311489  55.980333  111830.693403  2675.094520  0.336691
# 8  0.311736  0.311736  55.985596  111324.754340  2677.274642  0.336525
# 9  0.312657  0.312657  55.993793  112418.743924  2685.104785  0.336826
#
#    tst_elbo    tst_kl0        tst_klp  tst_log_pxz  ...  tst_mse_trgt*  \
# 0  0.338022  55.989768  112542.064757  4228.885666  ...       0.012027
# 1  0.336738  55.993511  112801.727951  4212.750803  ...       0.011466
# 2  0.335471  55.990538  110257.681250  4197.110655  ...       0.011036
# 3  0.337112  55.993533  113163.293056  4217.408691  ...       0.012020
# 4  0.335856  55.990159  119507.160937  4201.018001  ...       0.011802
# 5  0.336702  55.991873  111868.158681  4212.403212  ...       0.011445
# 6  0.337059  55.991981  110513.877604  4217.007726  ...       0.011743
# 7  0.336691  55.958013  109775.532639  4212.473242  ...       0.011575
# 8  0.336525  55.971810  108936.059028  4210.466829  ...       0.010890
# 9  0.336826  55.991981  109799.831944  4214.164605  ...       0.011338
#
#    val_loss  val_elbo    val_kl0        val_klp  val_log_pxz  val_mse_full  \
# 0  0.336025  0.336025  55.993793  113203.701389  4203.768880      0.010574
# 1  0.333905  0.333905  55.992166  113266.909722  4177.174316      0.009777
# 2  0.333836  0.333836  55.992925  110622.352431  4176.576063      0.009748
# 3  0.334723  0.334723  55.993793  114442.510417  4187.309679      0.010104
# 4  0.335526  0.335526  55.992166  120143.727431  4196.823947      0.010277
# 5  0.334430  0.334430  55.992925  110700.693576  4184.008192      0.009978
# 6  0.335996  0.335996  55.993793  110108.418403  4203.715061      0.010562
# 7  0.335628  0.335628  55.965039  111064.776042  4199.008138      0.010372
# 8  0.333803  0.333803  55.979579  110062.750000  4176.213379      0.009736
# 9  0.334788  0.334788  55.993793  111820.050347  4188.389648      0.010131
#
#    val_mse_trgt  val_mse_trgt*  epoch
# 0      0.011639       0.011207    990
# 1      0.010955       0.010821    990
# 2      0.010974       0.010602    990
# 3      0.011429       0.011159    990
# 4      0.011958       0.011348    990
# 5      0.011060       0.010763    990
# 6      0.011113       0.010894    990
# 7      0.011723       0.011362    990
# 8      0.010985       0.010531    990
# 9      0.011217       0.010788    990
#
# [10 rows x 22 columns]
